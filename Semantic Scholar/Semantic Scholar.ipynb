# %%
# Packages
from bs4 import BeautifulSoup
# import requests
import pandas as pd
import regex as re

# # Request to Semanticscholar
# url = 'https://semanticscholar.org/search?q=Computational%20Propaganda&sort=relevance'
# page = requests.get(url)
# soup1 = BeautifulSoup(page.content, 'html.parser')

# # Open html from a file
with open("/Users/tomasnagy/Documents/Weizenbaum - Work/Semantic Scholar/computational propaganda _ Semantic Scholar.html") as file:
    soup = BeautifulSoup(file, 'html.parser')

# %%
# Get the Title
results = []
for entry in soup.find_all('h2', class_='cl-paper-title'):
    results.append({"Title": entry.text})  
dataframe1 = pd.DataFrame(results)

# %%
# Get the Authors
results2 = []
for entry in soup.find_all('span', class_='cl-paper-authors'):
    results2.append({"Author": entry.text})    
dataframe2 = pd.DataFrame(results2)

# %%
# Get the Publication Date
results3 = []
for entry in soup.find_all('span', class_='cl-paper-pubdates'):
    results3.append({"Publication date": entry.text})    
dataframe3 = pd.DataFrame(results3)

# %%
# Get the Citations
results4 = []
for entry in soup.find_all('div', class_='cl-paper__bulleted-row cl-paper-controls'):
    if entry.find_all("div", {"class": "cl-paper-stats__action-stat"}):
        for item in entry.find_all("div", {"class": "cl-paper-stats__action-stat"}):
            results4.append({"Number of citation": item.text})   
    else:
        results4.append({"Number of citation": '0'}) 
dataframe4 = pd.DataFrame(results4)

# %%
# Get the Publisher
results5 = []
for entry in soup.find_all('ul', class_='cl-paper__bulleted-row'):
    if entry.find_all("span", {"class": "cl-paper-fos"}):
        for item in entry.find_all("span", {"class": "cl-paper-fos"}):
            results5.append({"Publisher": item.text})   
    else:
        results5.append({"Publisher": 'No publisher found'})
dataframe5 = pd.DataFrame(results5)

# %%
# Get the Link
results6 = []

for entry in soup.find_all('div', class_ = 'flex-row cl-paper-actions'):
    if entry.find_all('a', href=True):
        for a in entry.find_all('a', href=True):
            results6.append({"Link": a['href']})
    else:
        results6.append({"Link": 'Link not found'})
dataframe6 = pd.DataFrame(results6)

# %%
# Merge everything into one dataframe
dataframe = pd.concat([dataframe1, dataframe2,dataframe3,dataframe4,dataframe5,dataframe6], axis=1)
dataframe.to_csv('Smenatic Scholar - publications', sep='\t')

# %%
dataframe
# Out:
#                                                Title  \
# 0     A Survey on Computational Propaganda Detection
# 1  Computational propaganda: political parties, p...
# 2  The Connotation, Features, and Mechanism of Co...
# 3       Computational Propaganda in Hashtag Activism
# 4  Tricked into Supporting: A Study on Computatio...
# 5  Towards an Online Risk Mitigation Framework fo...
# 6  Computational Propaganda: Challenges and Respo...
# 7          The evolution of computational propaganda
# 8  Social media, computational propaganda, and co...
# 9  UNDERSTANDING COMPUTATIONAL PROPAGANDA: CHALLE...
#
#                                               Author  Publication date  \
# 0  Giovanni Da San Martino, S. Cresci, Alberto Ba...       1 July 2020
# 1                                    Emily Bienvenue      1 March 2020
# 2                                           Jin Yang              2021
# 3                           Andhika Kurniawan Pontoh   7 December 2021
# 4                                   Valentina Nerino     22 April 2021
# 5                          R. Robertson, C. Meintjes    2 January 2021
# 6                                  Federico DAlessio              2021
# 7                D. Tsyrenzhapova, Samuel C. Woolley     23 March 2021
# 8                                        G. Bolsover     24 March 2021
# 9                        Federico Alistair D'Alessio  4 September 2021
#
#   Number of citation           Publisher  \
# 0                 79    Computer Science
# 1                135   Political Science
# 2                  1            Business
# 3                  0  No publisher found
# 4                  0    Computer Science
# 5                  0            Business
# 6                  0    Computer Science
# 7                  1  No publisher found
# 8                  2   Political Science
# 9                  0  No publisher found
#
#                                                 Link
# 0               https://arxiv.org/pdf/2007.08024.pdf
# 1               https://doi.org/10.1093/ia%2Fiiaa018
# 2  https://pdfs.semanticscholar.org/f5f6/0cf73e85...
# 3            https://doi.org/10.24912/jk.v13i2.11086
# 4            https://doi.org/10.13136/ISR.V11I4S.438
# 5      https://doi.org/10.1080/02500167.2021.1884578
# 6                                     Link not found
# 7           https://doi.org/10.4324/9781003004431-14
# 8           https://doi.org/10.4324/9781003046905-11
# 9                    https://doi.org/10.20935/al3468
